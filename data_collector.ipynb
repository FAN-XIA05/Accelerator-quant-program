# %%
pip install pandas_datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas_datareader) (5.3.0)
# Requirement already satisfied: pandas>=0.23 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas_datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas_datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.15.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import json
import os
import time
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import pandas_datareader.data as web

# %%
class SP500DataCollector:
    def __init__(self):
        # 加载配置
        with open('config.json', 'r') as f:
            self.config = json.load(f)
        
        # 创建数据存储文件夹
        for folder in ['stock_data_folder', 'factor_data_folder']:
            folder_path = self.config['output_settings'][folder]
            if not os.path.exists(folder_path):
                os.makedirs(folder_path)

    def get_sp500_list(self):
        """获取S&P500成分股列表"""
        url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', {'class': 'wikitable'})
        
        df = pd.DataFrame(columns=['Symbol', 'Company', 'Sector'])
        
        for row in table.findAll('tr')[1:]:
            cols = row.findAll('td')
            if len(cols) >= 3:
                symbol = cols[0].text.strip()
                company = cols[1].text.strip()
                sector = cols[3].text.strip()
                df = pd.concat([df, pd.DataFrame({
                    'Symbol': [symbol],
                    'Company': [company],
                    'Sector': [sector]
                })], ignore_index=True)
        
        # 添加验证
        if len(df) != 500:
            print(f"警告：获取到的SP500公司数量为 {len(df)}，而不是500家")
        
        # 保存SP500列表
        df.to_csv(self.config['output_settings']['sp500_list_file'], index=False)
        return df

    def get_stock_data(self, symbol):
        """获取单个股票的历史数据"""
        settings = self.config['data_settings']
        stock = yf.Ticker(symbol)
        
        try:
            data = stock.history(
                start=settings['start_date'],
                end=settings['end_date']
            )
            
            # 只保留配置文件中指定的指标
            data = data[settings['indicators']]
            
            # 保存数据
            output_path = os.path.join(
                self.config['output_settings']['stock_data_folder'],
                f"{symbol}.csv"
            )
            data.to_csv(output_path)
            return True
        except Exception as e:
            print(f"获取 {symbol} 数据时出错: {str(e)}")
            return False

    def calculate_technical_factors(self, data):
        """计算技术面因子"""
        tech_settings = self.config['factor_settings']['technical_factors']
        
        # 计算动量因子
        for period in tech_settings['momentum_periods']:
            data[f'momentum_{period}d'] = data['Close'].pct_change(period)
        
        # 计算RSI
        def calculate_rsi(prices, period=14):
            delta = prices.diff()
            gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
            loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
            rs = gain / loss
            return 100 - (100 / (1 + rs))
        
        data['RSI'] = calculate_rsi(data['Close'], tech_settings['rsi_period'])
        
        # 计算MACD
        macd_params = tech_settings['macd_params']
        exp1 = data['Close'].ewm(span=macd_params['fast_period']).mean()
        exp2 = data['Close'].ewm(span=macd_params['slow_period']).mean()
        data['MACD'] = exp1 - exp2
        data['Signal_Line'] = data['MACD'].ewm(span=macd_params['signal_period']).mean()
        data['MACD_Histogram'] = data['MACD'] - data['Signal_Line']
        
        return data

    def get_fundamental_factors(self, symbol):
        """获取基本面因子"""
        stock = yf.Ticker(symbol)
        fund_metrics = {}
        
        # 获取基本面指标
        try:
            info = stock.info
            metrics = self.config['factor_settings']['fundamental_factors']['metrics']
            
            for metric in metrics:
                fund_metrics[metric] = info.get(metric, None)
                
            # 获取财务报表数据
            financials = stock.financials
            if not financials.empty:
                # 计算净利润增长率
                net_income = financials.loc['Net Income']
                fund_metrics['net_income_growth'] = (
                    (net_income.iloc[0] - net_income.iloc[1]) / 
                    abs(net_income.iloc[1]) * 100 if len(net_income) >= 2 else None
                )
        except Exception as e:
            print(f"获取 {symbol} 基本面数据时出错: {str(e)}")
        
        return fund_metrics

    def get_market_factors(self):
        """获取Fama-French三因子数据"""
        try:
            ff_factors = web.DataReader(
                'F-F_Research_Data_Factors_daily',
                'famafrench',
                start=self.config['data_settings']['start_date'],
                end=self.config['data_settings']['end_date']
            )[0]
            
            # 将百分比转换为小数
            ff_factors = ff_factors / 100
            
            # 保存因子数据
            output_path = os.path.join(
                self.config['output_settings']['factor_data_folder'],
                'ff_factors.csv'
            )
            ff_factors.to_csv(output_path)
            return ff_factors
        except Exception as e:
            print(f"获取Fama-French因子数据时出错: {str(e)}")
            return None

    def process_stock_data(self, symbol):
        """处理单个股票的所有数据"""
        settings = self.config['data_settings']
        stock = yf.Ticker(symbol)
        
        try:
            # 获取价格数据
            data = stock.history(
                start=settings['start_date'],
                end=settings['end_date']
            )
            
            # 计算技术面因子
            if self.config['factor_settings']['technical_factors']['enabled']:
                data = self.calculate_technical_factors(data)
            
            # 获取基本面因子
            if self.config['factor_settings']['fundamental_factors']['enabled']:
                fund_factors = self.get_fundamental_factors(symbol)
                # 将基本面因子添加为常量列
                for factor, value in fund_factors.items():
                    data[factor] = value
            
            # 保存数据
            output_path = os.path.join(
                self.config['output_settings']['stock_data_folder'],
                f"{symbol}_full.csv"
            )
            data.to_csv(output_path)
            return True
        except Exception as e:
            print(f"处理 {symbol} 数据时出错: {str(e)}")
            return False

    def collect_all_data(self):
        """收集所有数据"""
        # 获取市场因子
        if self.config['factor_settings']['market_factors']['enabled']:
            print("正在获取Fama-French因子数据...")
            self.get_market_factors()
        
        # 获取SP500列表
        sp500_df = self.get_sp500_list()
        print(f"获取到 {len(sp500_df)} 个SP500成分股")

        # 处理每个股票的数据
        for index, row in sp500_df.iterrows():
            symbol = row['Symbol']
            print(f"正在处理 {symbol} 的数据...")
            
            success = False
            retries = self.config['api_settings']['retry_times']
            
            while retries > 0 and not success:
                success = self.process_stock_data(symbol)
                if not success:
                    retries -= 1
                    time.sleep(self.config['api_settings']['sleep_between_calls'])
            
            if success:
                print(f"{symbol} 数据处理成功")
            else:
                print(f"{symbol} 数据处理失败")

# %%
def main():
    collector = SP500DataCollector()
    collector.collect_all_data()

if __name__ == "__main__":
    main()
# Out:
# 正在获取Fama-French因子数据...
# /var/folders/cw/yxxjm9s13cz54l3wm4btmtnc0000gn/T/ipykernel_35938/2414291931.py:125: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   ff_factors = web.DataReader(
# 警告：获取到的SP500公司数量为 503，而不是500家
# 获取到 503 个SP500成分股
# 正在处理 MMM 的数据...
# MMM 数据处理成功
# 正在处理 AOS 的数据...
# AOS 数据处理成功
# 正在处理 ABT 的数据...
# ABT 数据处理成功
# 正在处理 ABBV 的数据...
# ABBV 数据处理成功
# 正在处理 ACN 的数据...
# ACN 数据处理成功
# 正在处理 ADBE 的数据...
# ADBE 数据处理成功
# 正在处理 AMD 的数据...
# AMD 数据处理成功
# 正在处理 AES 的数据...
# AES 数据处理成功
# 正在处理 AFL 的数据...
# AFL 数据处理成功
# 正在处理 A 的数据...
# A 数据处理成功
# 正在处理 APD 的数据...
# APD 数据处理成功
# 正在处理 ABNB 的数据...
# ABNB 数据处理成功
# 正在处理 AKAM 的数据...
# AKAM 数据处理成功
# 正在处理 ALB 的数据...
# ALB 数据处理成功
# 正在处理 ARE 的数据...
# ARE 数据处理成功
# 正在处理 ALGN 的数据...
# ALGN 数据处理成功
# 正在处理 ALLE 的数据...
# ALLE 数据处理成功
# 正在处理 LNT 的数据...
# LNT 数据处理成功
# 正在处理 ALL 的数据...
# ALL 数据处理成功
# 正在处理 GOOGL 的数据...
# GOOGL 数据处理成功
# 正在处理 GOOG 的数据...
# GOOG 数据处理成功
# 正在处理 MO 的数据...
# MO 数据处理成功
# 正在处理 AMZN 的数据...
# AMZN 数据处理成功
# 正在处理 AMCR 的数据...
# AMCR 数据处理成功
# 正在处理 AEE 的数据...
# AEE 数据处理成功
# 正在处理 AEP 的数据...
# AEP 数据处理成功
# 正在处理 AXP 的数据...
# AXP 数据处理成功
# 正在处理 AIG 的数据...
# AIG 数据处理成功
# 正在处理 AMT 的数据...
# AMT 数据处理成功
# 正在处理 AWK 的数据...
# AWK 数据处理成功
# 正在处理 AMP 的数据...
# AMP 数据处理成功
# 正在处理 AME 的数据...
# AME 数据处理成功
# 正在处理 AMGN 的数据...
# AMGN 数据处理成功
# 正在处理 APH 的数据...
# APH 数据处理成功
# 正在处理 ADI 的数据...
# ADI 数据处理成功
# 正在处理 ANSS 的数据...
# ANSS 数据处理成功
# 正在处理 AON 的数据...
# AON 数据处理成功
# 正在处理 APA 的数据...
# APA 数据处理成功
# 正在处理 APO 的数据...
# APO 数据处理成功
# 正在处理 AAPL 的数据...
# AAPL 数据处理成功
# 正在处理 AMAT 的数据...
# AMAT 数据处理成功
# 正在处理 APTV 的数据...
# APTV 数据处理成功
# 正在处理 ACGL 的数据...
# ACGL 数据处理成功
# 正在处理 ADM 的数据...
# ADM 数据处理成功
# 正在处理 ANET 的数据...
# ANET 数据处理成功
# 正在处理 AJG 的数据...
# AJG 数据处理成功
# 正在处理 AIZ 的数据...
# AIZ 数据处理成功
# 正在处理 T 的数据...
# T 数据处理成功
# 正在处理 ATO 的数据...
# ATO 数据处理成功
# 正在处理 ADSK 的数据...
# ADSK 数据处理成功
# 正在处理 ADP 的数据...
# ADP 数据处理成功
# 正在处理 AZO 的数据...
# AZO 数据处理成功
# 正在处理 AVB 的数据...
# AVB 数据处理成功
# 正在处理 AVY 的数据...
# AVY 数据处理成功
# 正在处理 AXON 的数据...
# AXON 数据处理成功
# 正在处理 BKR 的数据...
# BKR 数据处理成功
# 正在处理 BALL 的数据...
# BALL 数据处理成功
# 正在处理 BAC 的数据...
# BAC 数据处理成功
# 正在处理 BAX 的数据...
# BAX 数据处理成功
# 正在处理 BDX 的数据...
# BDX 数据处理成功
# 正在处理 BRK.B 的数据...
# $BRK.B: possibly delisted; no timezone found
# BRK.B 数据处理成功
# 正在处理 BBY 的数据...
# BBY 数据处理成功
# 正在处理 TECH 的数据...
# TECH 数据处理成功
# 正在处理 BIIB 的数据...
# BIIB 数据处理成功
# 正在处理 BLK 的数据...
# BLK 数据处理成功
# 正在处理 BX 的数据...
# BX 数据处理成功
# 正在处理 BK 的数据...
# BK 数据处理成功
# 正在处理 BA 的数据...
# BA 数据处理成功
# 正在处理 BKNG 的数据...
# BKNG 数据处理成功
# 正在处理 BWA 的数据...
# BWA 数据处理成功
# 正在处理 BSX 的数据...
# BSX 数据处理成功
# 正在处理 BMY 的数据...
# BMY 数据处理成功
# 正在处理 AVGO 的数据...
# AVGO 数据处理成功
# 正在处理 BR 的数据...
# BR 数据处理成功
# 正在处理 BRO 的数据...
# $BF.B: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-03-20)
# BRO 数据处理成功
# 正在处理 BF.B 的数据...
# BF.B 数据处理成功
# 正在处理 BLDR 的数据...
# BLDR 数据处理成功
# 正在处理 BG 的数据...
# BG 数据处理成功
# 正在处理 BXP 的数据...
# BXP 数据处理成功
# 正在处理 CHRW 的数据...
# CHRW 数据处理成功
# 正在处理 CDNS 的数据...
# CDNS 数据处理成功
# 正在处理 CZR 的数据...
# CZR 数据处理成功
# 正在处理 CPT 的数据...
# CPT 数据处理成功
# 正在处理 CPB 的数据...
# CPB 数据处理成功
# 正在处理 COF 的数据...
# COF 数据处理成功
# 正在处理 CAH 的数据...
# CAH 数据处理成功
# 正在处理 KMX 的数据...
# KMX 数据处理成功
# 正在处理 CCL 的数据...
# CCL 数据处理成功
# 正在处理 CARR 的数据...
# CARR 数据处理成功
# 正在处理 CAT 的数据...
# CAT 数据处理成功
# 正在处理 CBOE 的数据...
# CBOE 数据处理成功
# 正在处理 CBRE 的数据...
# CBRE 数据处理成功
# 正在处理 CDW 的数据...
# CDW 数据处理成功
# 正在处理 CE 的数据...
# CE 数据处理成功
# 正在处理 COR 的数据...
# COR 数据处理成功
# 正在处理 CNC 的数据...
# CNC 数据处理成功
# 正在处理 CNP 的数据...
# CNP 数据处理成功
# 正在处理 CF 的数据...
# CF 数据处理成功
# 正在处理 CRL 的数据...
# CRL 数据处理成功
# 正在处理 SCHW 的数据...
# SCHW 数据处理成功
# 正在处理 CHTR 的数据...
# CHTR 数据处理成功
# 正在处理 CVX 的数据...
# CVX 数据处理成功
# 正在处理 CMG 的数据...
# CMG 数据处理成功
# 正在处理 CB 的数据...
# CB 数据处理成功
# 正在处理 CHD 的数据...
# CHD 数据处理成功
# 正在处理 CI 的数据...
# CI 数据处理成功
# 正在处理 CINF 的数据...
# CINF 数据处理成功
# 正在处理 CTAS 的数据...
# CTAS 数据处理成功
# 正在处理 CSCO 的数据...
# CSCO 数据处理成功
# 正在处理 C 的数据...
# C 数据处理成功
# 正在处理 CFG 的数据...
# CFG 数据处理成功
# 正在处理 CLX 的数据...
# CLX 数据处理成功
# 正在处理 CME 的数据...
# CME 数据处理成功
# 正在处理 CMS 的数据...
# CMS 数据处理成功
# 正在处理 KO 的数据...
# KO 数据处理成功
# 正在处理 CTSH 的数据...
# CTSH 数据处理成功
# 正在处理 CL 的数据...
# CL 数据处理成功
# 正在处理 CMCSA 的数据...
# CMCSA 数据处理成功
# 正在处理 CAG 的数据...
# CAG 数据处理成功
# 正在处理 COP 的数据...
# COP 数据处理成功
# 正在处理 ED 的数据...
# ED 数据处理成功
# 正在处理 STZ 的数据...
# STZ 数据处理成功
# 正在处理 CEG 的数据...
# CEG 数据处理成功
# 正在处理 COO 的数据...
# COO 数据处理成功
# 正在处理 CPRT 的数据...
# CPRT 数据处理成功
# 正在处理 GLW 的数据...
# GLW 数据处理成功
# 正在处理 CPAY 的数据...
# CPAY 数据处理成功
# 正在处理 CTVA 的数据...
# CTVA 数据处理成功
# 正在处理 CSGP 的数据...
# CSGP 数据处理成功
# 正在处理 COST 的数据...
# COST 数据处理成功
# 正在处理 CTRA 的数据...
# CTRA 数据处理成功
# 正在处理 CRWD 的数据...
# CRWD 数据处理成功
# 正在处理 CCI 的数据...
# CCI 数据处理成功
# 正在处理 CSX 的数据...
# CSX 数据处理成功
# 正在处理 CMI 的数据...
# CMI 数据处理成功
# 正在处理 CVS 的数据...
# CVS 数据处理成功
# 正在处理 DHR 的数据...
# DHR 数据处理成功
# 正在处理 DRI 的数据...
# DRI 数据处理成功
# 正在处理 DVA 的数据...
# DVA 数据处理成功
# 正在处理 DAY 的数据...
# DAY 数据处理成功
# 正在处理 DECK 的数据...
# DECK 数据处理成功
# 正在处理 DE 的数据...
# DE 数据处理成功
# 正在处理 DELL 的数据...
# DELL 数据处理成功
# 正在处理 DAL 的数据...
# DAL 数据处理成功
# 正在处理 DVN 的数据...
# DVN 数据处理成功
# 正在处理 DXCM 的数据...
# DXCM 数据处理成功
# 正在处理 FANG 的数据...
# FANG 数据处理成功
# 正在处理 DLR 的数据...
# DLR 数据处理成功
# 正在处理 DFS 的数据...
# DFS 数据处理成功
# 正在处理 DG 的数据...
# DG 数据处理成功
# 正在处理 DLTR 的数据...
# DLTR 数据处理成功
# 正在处理 D 的数据...
# D 数据处理成功
# 正在处理 DPZ 的数据...
# DPZ 数据处理成功
# 正在处理 DOV 的数据...
# DOV 数据处理成功
# 正在处理 DOW 的数据...
# DOW 数据处理成功
# 正在处理 DHI 的数据...
# DHI 数据处理成功
# 正在处理 DTE 的数据...
# DTE 数据处理成功
# 正在处理 DUK 的数据...
# DUK 数据处理成功
# 正在处理 DD 的数据...
# DD 数据处理成功
# 正在处理 EMN 的数据...
# EMN 数据处理成功
# 正在处理 ETN 的数据...
# ETN 数据处理成功
# 正在处理 EBAY 的数据...
# EBAY 数据处理成功
# 正在处理 ECL 的数据...
# ECL 数据处理成功
# 正在处理 EIX 的数据...
# EIX 数据处理成功
# 正在处理 EW 的数据...
# EW 数据处理成功
# 正在处理 EA 的数据...
# EA 数据处理成功
# 正在处理 ELV 的数据...
# ELV 数据处理成功
# 正在处理 EMR 的数据...
# EMR 数据处理成功
# 正在处理 ENPH 的数据...
# ENPH 数据处理成功
# 正在处理 ETR 的数据...
# ETR 数据处理成功
# 正在处理 EOG 的数据...
# EOG 数据处理成功
# 正在处理 EPAM 的数据...
# EPAM 数据处理成功
# 正在处理 EQT 的数据...
# EQT 数据处理成功
# 正在处理 EFX 的数据...
# EFX 数据处理成功
# 正在处理 EQIX 的数据...
# EQIX 数据处理成功
# 正在处理 EQR 的数据...
# EQR 数据处理成功
# 正在处理 ERIE 的数据...
# ERIE 数据处理成功
# 正在处理 ESS 的数据...
# ESS 数据处理成功
# 正在处理 EL 的数据...
# EL 数据处理成功
# 正在处理 EG 的数据...
# EG 数据处理成功
# 正在处理 EVRG 的数据...
# EVRG 数据处理成功
# 正在处理 ES 的数据...
# ES 数据处理成功
# 正在处理 EXC 的数据...
# EXC 数据处理成功
# 正在处理 EXPE 的数据...
# EXPE 数据处理成功
# 正在处理 EXPD 的数据...
# EXPD 数据处理成功
# 正在处理 EXR 的数据...
# EXR 数据处理成功
# 正在处理 XOM 的数据...
# XOM 数据处理成功
# 正在处理 FFIV 的数据...
# FFIV 数据处理成功
# 正在处理 FDS 的数据...
# FDS 数据处理成功
# 正在处理 FICO 的数据...
# FICO 数据处理成功
# 正在处理 FAST 的数据...
# FAST 数据处理成功
# 正在处理 FRT 的数据...
# FRT 数据处理成功
# 正在处理 FDX 的数据...
# FDX 数据处理成功
# 正在处理 FIS 的数据...
# FIS 数据处理成功
# 正在处理 FITB 的数据...
# FITB 数据处理成功
# 正在处理 FSLR 的数据...
# FSLR 数据处理成功
# 正在处理 FE 的数据...
# FE 数据处理成功
# 正在处理 FI 的数据...
# FI 数据处理成功
# 正在处理 FMC 的数据...
# FMC 数据处理成功
# 正在处理 F 的数据...
# F 数据处理成功
# 正在处理 FTNT 的数据...
# FTNT 数据处理成功
# 正在处理 FTV 的数据...
# FTV 数据处理成功
# 正在处理 FOXA 的数据...
# FOXA 数据处理成功
# 正在处理 FOX 的数据...
# FOX 数据处理成功
# 正在处理 BEN 的数据...
# BEN 数据处理成功
# 正在处理 FCX 的数据...
# FCX 数据处理成功
# 正在处理 GRMN 的数据...
# GRMN 数据处理成功
# 正在处理 IT 的数据...
# IT 数据处理成功
# 正在处理 GE 的数据...
# GE 数据处理成功
# 正在处理 GEHC 的数据...
# GEHC 数据处理成功
# 正在处理 GEV 的数据...
# $GEV: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-03-20) (Yahoo error = "Data doesn't exist for startDate = 1641013200, endDate = 1710907200")
# GEV 数据处理成功
# 正在处理 GEN 的数据...
# GEN 数据处理成功
# 正在处理 GNRC 的数据...
# GNRC 数据处理成功
# 正在处理 GD 的数据...
# GD 数据处理成功
# 正在处理 GIS 的数据...
# GIS 数据处理成功
# 正在处理 GM 的数据...
# GM 数据处理成功
# 正在处理 GPC 的数据...
# GPC 数据处理成功
# 正在处理 GILD 的数据...
# GILD 数据处理成功
# 正在处理 GPN 的数据...
# GPN 数据处理成功
# 正在处理 GL 的数据...
# GL 数据处理成功
# 正在处理 GDDY 的数据...
# GDDY 数据处理成功
# 正在处理 GS 的数据...
# GS 数据处理成功
# 正在处理 HAL 的数据...
# HAL 数据处理成功
# 正在处理 HIG 的数据...
# HIG 数据处理成功
# 正在处理 HAS 的数据...
# HAS 数据处理成功
# 正在处理 HCA 的数据...
# HCA 数据处理成功
# 正在处理 DOC 的数据...
# DOC 数据处理成功
# 正在处理 HSIC 的数据...
# HSIC 数据处理成功
# 正在处理 HSY 的数据...
# HSY 数据处理成功
# 正在处理 HES 的数据...
# HES 数据处理成功
# 正在处理 HPE 的数据...
# HPE 数据处理成功
# 正在处理 HLT 的数据...
# HLT 数据处理成功
# 正在处理 HOLX 的数据...
# HOLX 数据处理成功
# 正在处理 HD 的数据...
# HD 数据处理成功
# 正在处理 HON 的数据...
# HON 数据处理成功
# 正在处理 HRL 的数据...
# HRL 数据处理成功
# 正在处理 HST 的数据...
# HST 数据处理成功
# 正在处理 HWM 的数据...
# HWM 数据处理成功
# 正在处理 HPQ 的数据...
# HPQ 数据处理成功
# 正在处理 HUBB 的数据...
# HUBB 数据处理成功
# 正在处理 HUM 的数据...
# HUM 数据处理成功
# 正在处理 HBAN 的数据...
# HBAN 数据处理成功
# 正在处理 HII 的数据...
# HII 数据处理成功
# 正在处理 IBM 的数据...
# IBM 数据处理成功
# 正在处理 IEX 的数据...
# IEX 数据处理成功
# 正在处理 IDXX 的数据...
# IDXX 数据处理成功
# 正在处理 ITW 的数据...
# ITW 数据处理成功
# 正在处理 INCY 的数据...
# INCY 数据处理成功
# 正在处理 IR 的数据...
# IR 数据处理成功
# 正在处理 PODD 的数据...
# PODD 数据处理成功
# 正在处理 INTC 的数据...
# INTC 数据处理成功
# 正在处理 ICE 的数据...
# ICE 数据处理成功
# 正在处理 IFF 的数据...
# IFF 数据处理成功
# 正在处理 IP 的数据...
# IP 数据处理成功
# 正在处理 IPG 的数据...
# IPG 数据处理成功
# 正在处理 INTU 的数据...
# INTU 数据处理成功
# 正在处理 ISRG 的数据...
# ISRG 数据处理成功
# 正在处理 IVZ 的数据...
# IVZ 数据处理成功
# 正在处理 INVH 的数据...
# INVH 数据处理成功
# 正在处理 IQV 的数据...
# IQV 数据处理成功
# 正在处理 IRM 的数据...
# IRM 数据处理成功
# 正在处理 JBHT 的数据...
# JBHT 数据处理成功
# 正在处理 JBL 的数据...
# JBL 数据处理成功
# 正在处理 JKHY 的数据...
# JKHY 数据处理成功
# 正在处理 J 的数据...
# J 数据处理成功
# 正在处理 JNJ 的数据...
# JNJ 数据处理成功
# 正在处理 JCI 的数据...
# JCI 数据处理成功
# 正在处理 JPM 的数据...
# JPM 数据处理成功
# 正在处理 JNPR 的数据...
# JNPR 数据处理成功
# 正在处理 K 的数据...
# K 数据处理成功
# 正在处理 KVUE 的数据...
# KVUE 数据处理成功
# 正在处理 KDP 的数据...
# KDP 数据处理成功
# 正在处理 KEY 的数据...
# KEY 数据处理成功
# 正在处理 KEYS 的数据...
# KEYS 数据处理成功
# 正在处理 KMB 的数据...
# KMB 数据处理成功
# 正在处理 KIM 的数据...
# KIM 数据处理成功
# 正在处理 KMI 的数据...
# KMI 数据处理成功
# 正在处理 KKR 的数据...
# KKR 数据处理成功
# 正在处理 KLAC 的数据...
# KLAC 数据处理成功
# 正在处理 KHC 的数据...
# KHC 数据处理成功
# 正在处理 KR 的数据...
# KR 数据处理成功
# 正在处理 LHX 的数据...
# LHX 数据处理成功
# 正在处理 LH 的数据...
# LH 数据处理成功
# 正在处理 LRCX 的数据...
# LRCX 数据处理成功
# 正在处理 LW 的数据...
# LW 数据处理成功
# 正在处理 LVS 的数据...
# LVS 数据处理成功
# 正在处理 LDOS 的数据...
# LDOS 数据处理成功
# 正在处理 LEN 的数据...
# LEN 数据处理成功
# 正在处理 LII 的数据...
# LII 数据处理成功
# 正在处理 LLY 的数据...
# LLY 数据处理成功
# 正在处理 LIN 的数据...
# LIN 数据处理成功
# 正在处理 LYV 的数据...
# LYV 数据处理成功
# 正在处理 LKQ 的数据...
# LKQ 数据处理成功
# 正在处理 LMT 的数据...
# LMT 数据处理成功
# 正在处理 L 的数据...
# L 数据处理成功
# 正在处理 LOW 的数据...
# LOW 数据处理成功
# 正在处理 LULU 的数据...
# LULU 数据处理成功
# 正在处理 LYB 的数据...
# LYB 数据处理成功
# 正在处理 MTB 的数据...
# MTB 数据处理成功
# 正在处理 MPC 的数据...
# MPC 数据处理成功
# 正在处理 MKTX 的数据...
# MKTX 数据处理成功
# 正在处理 MAR 的数据...
# MAR 数据处理成功
# 正在处理 MMC 的数据...
# MMC 数据处理成功
# 正在处理 MLM 的数据...
# MLM 数据处理成功
# 正在处理 MAS 的数据...
# MAS 数据处理成功
# 正在处理 MA 的数据...
# MA 数据处理成功
# 正在处理 MTCH 的数据...
# MTCH 数据处理成功
# 正在处理 MKC 的数据...
# MKC 数据处理成功
# 正在处理 MCD 的数据...
# MCD 数据处理成功
# 正在处理 MCK 的数据...
# MCK 数据处理成功
# 正在处理 MDT 的数据...
# MDT 数据处理成功
# 正在处理 MRK 的数据...
# MRK 数据处理成功
# 正在处理 META 的数据...
# META 数据处理成功
# 正在处理 MET 的数据...
# MET 数据处理成功
# 正在处理 MTD 的数据...
# MTD 数据处理成功
# 正在处理 MGM 的数据...
# MGM 数据处理成功
# 正在处理 MCHP 的数据...
# MCHP 数据处理成功
# 正在处理 MU 的数据...
# MU 数据处理成功
# 正在处理 MSFT 的数据...
# MSFT 数据处理成功
# 正在处理 MAA 的数据...
# MAA 数据处理成功
# 正在处理 MRNA 的数据...
# MRNA 数据处理成功
# 正在处理 MHK 的数据...
# MHK 数据处理成功
# 正在处理 MOH 的数据...
# MOH 数据处理成功
# 正在处理 TAP 的数据...
# TAP 数据处理成功
# 正在处理 MDLZ 的数据...
# MDLZ 数据处理成功
# 正在处理 MPWR 的数据...
# MPWR 数据处理成功
# 正在处理 MNST 的数据...
# MNST 数据处理成功
# 正在处理 MCO 的数据...
# MCO 数据处理成功
# 正在处理 MS 的数据...
# MS 数据处理成功
# 正在处理 MOS 的数据...
# MOS 数据处理成功
# 正在处理 MSI 的数据...
# MSI 数据处理成功
# 正在处理 MSCI 的数据...
# MSCI 数据处理成功
# 正在处理 NDAQ 的数据...
# NDAQ 数据处理成功
# 正在处理 NTAP 的数据...
# NTAP 数据处理成功
# 正在处理 NFLX 的数据...
# NFLX 数据处理成功
# 正在处理 NEM 的数据...
# NEM 数据处理成功
# 正在处理 NWSA 的数据...
# NWSA 数据处理成功
# 正在处理 NWS 的数据...
# NWS 数据处理成功
# 正在处理 NEE 的数据...
# NEE 数据处理成功
# 正在处理 NKE 的数据...
# NKE 数据处理成功
# 正在处理 NI 的数据...
# NI 数据处理成功
# 正在处理 NDSN 的数据...
# NDSN 数据处理成功
# 正在处理 NSC 的数据...
# NSC 数据处理成功
# 正在处理 NTRS 的数据...
# NTRS 数据处理成功
# 正在处理 NOC 的数据...
# NOC 数据处理成功
# 正在处理 NCLH 的数据...
# NCLH 数据处理成功
# 正在处理 NRG 的数据...
# NRG 数据处理成功
# 正在处理 NUE 的数据...
# NUE 数据处理成功
# 正在处理 NVDA 的数据...
# NVDA 数据处理成功
# 正在处理 NVR 的数据...
# NVR 数据处理成功
# 正在处理 NXPI 的数据...
# NXPI 数据处理成功
# 正在处理 ORLY 的数据...
# ORLY 数据处理成功
# 正在处理 OXY 的数据...
# OXY 数据处理成功
# 正在处理 ODFL 的数据...
# ODFL 数据处理成功
# 正在处理 OMC 的数据...
# OMC 数据处理成功
# 正在处理 ON 的数据...
# ON 数据处理成功
# 正在处理 OKE 的数据...
# OKE 数据处理成功
# 正在处理 ORCL 的数据...
# ORCL 数据处理成功
# 正在处理 OTIS 的数据...
# OTIS 数据处理成功
# 正在处理 PCAR 的数据...
# PCAR 数据处理成功
# 正在处理 PKG 的数据...
# PKG 数据处理成功
# 正在处理 PLTR 的数据...
# PLTR 数据处理成功
# 正在处理 PANW 的数据...
# PANW 数据处理成功
# 正在处理 PARA 的数据...
# PARA 数据处理成功
# 正在处理 PH 的数据...
# PH 数据处理成功
# 正在处理 PAYX 的数据...
# PAYX 数据处理成功
# 正在处理 PAYC 的数据...
# PAYC 数据处理成功
# 正在处理 PYPL 的数据...
# PYPL 数据处理成功
# 正在处理 PNR 的数据...
# PNR 数据处理成功
# 正在处理 PEP 的数据...
# PEP 数据处理成功
# 正在处理 PFE 的数据...
# PFE 数据处理成功
# 正在处理 PCG 的数据...
# PCG 数据处理成功
# 正在处理 PM 的数据...
# PM 数据处理成功
# 正在处理 PSX 的数据...
# PSX 数据处理成功
# 正在处理 PNW 的数据...
# PNW 数据处理成功
# 正在处理 PNC 的数据...
# PNC 数据处理成功
# 正在处理 POOL 的数据...
# POOL 数据处理成功
# 正在处理 PPG 的数据...
# PPG 数据处理成功
# 正在处理 PPL 的数据...
# PPL 数据处理成功
# 正在处理 PFG 的数据...
# PFG 数据处理成功
# 正在处理 PG 的数据...
# PG 数据处理成功
# 正在处理 PGR 的数据...
# PGR 数据处理成功
# 正在处理 PLD 的数据...
# PLD 数据处理成功
# 正在处理 PRU 的数据...
# PRU 数据处理成功
# 正在处理 PEG 的数据...
# PEG 数据处理成功
# 正在处理 PTC 的数据...
# PTC 数据处理成功
# 正在处理 PSA 的数据...
# PSA 数据处理成功
# 正在处理 PHM 的数据...
# PHM 数据处理成功
# 正在处理 PWR 的数据...
# PWR 数据处理成功
# 正在处理 QCOM 的数据...
# QCOM 数据处理成功
# 正在处理 DGX 的数据...
# DGX 数据处理成功
# 正在处理 RL 的数据...
# RL 数据处理成功
# 正在处理 RJF 的数据...
# RJF 数据处理成功
# 正在处理 RTX 的数据...
# RTX 数据处理成功
# 正在处理 O 的数据...
# O 数据处理成功
# 正在处理 REG 的数据...
# REG 数据处理成功
# 正在处理 REGN 的数据...
# REGN 数据处理成功
# 正在处理 RF 的数据...
# RF 数据处理成功
# 正在处理 RSG 的数据...
# RSG 数据处理成功
# 正在处理 RMD 的数据...
# RMD 数据处理成功
# 正在处理 RVTY 的数据...
# RVTY 数据处理成功
# 正在处理 ROK 的数据...
# ROK 数据处理成功
# 正在处理 ROL 的数据...
# ROL 数据处理成功
# 正在处理 ROP 的数据...
# ROP 数据处理成功
# 正在处理 ROST 的数据...
# ROST 数据处理成功
# 正在处理 RCL 的数据...
# RCL 数据处理成功
# 正在处理 SPGI 的数据...
# SPGI 数据处理成功
# 正在处理 CRM 的数据...
# CRM 数据处理成功
# 正在处理 SBAC 的数据...
# SBAC 数据处理成功
# 正在处理 SLB 的数据...
# SLB 数据处理成功
# 正在处理 STX 的数据...
# STX 数据处理成功
# 正在处理 SRE 的数据...
# SRE 数据处理成功
# 正在处理 NOW 的数据...
# NOW 数据处理成功
# 正在处理 SHW 的数据...
# SHW 数据处理成功
# 正在处理 SPG 的数据...
# SPG 数据处理成功
# 正在处理 SWKS 的数据...
# SWKS 数据处理成功
# 正在处理 SJM 的数据...
# SJM 数据处理成功
# 正在处理 SW 的数据...
# $SW: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-03-20) (Yahoo error = "Data doesn't exist for startDate = 1641013200, endDate = 1710907200")
# SW 数据处理成功
# 正在处理 SNA 的数据...
# SNA 数据处理成功
# 正在处理 SOLV 的数据...
# $SOLV: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-03-20) (Yahoo error = "Data doesn't exist for startDate = 1641013200, endDate = 1710907200")
# SOLV 数据处理成功
# 正在处理 SO 的数据...
# SO 数据处理成功
# 正在处理 LUV 的数据...
# LUV 数据处理成功
# 正在处理 SWK 的数据...
# SWK 数据处理成功
# 正在处理 SBUX 的数据...
# SBUX 数据处理成功
# 正在处理 STT 的数据...
# STT 数据处理成功
# 正在处理 STLD 的数据...
# STLD 数据处理成功
# 正在处理 STE 的数据...
# STE 数据处理成功
# 正在处理 SYK 的数据...
# SYK 数据处理成功
# 正在处理 SMCI 的数据...
# SMCI 数据处理成功
# 正在处理 SYF 的数据...
# SYF 数据处理成功
# 正在处理 SNPS 的数据...
# SNPS 数据处理成功
# 正在处理 SYY 的数据...
# SYY 数据处理成功
# 正在处理 TMUS 的数据...
# TMUS 数据处理成功
# 正在处理 TROW 的数据...
# TROW 数据处理成功
# 正在处理 TTWO 的数据...
# TTWO 数据处理成功
# 正在处理 TPR 的数据...
# TPR 数据处理成功
# 正在处理 TRGP 的数据...
# TRGP 数据处理成功
# 正在处理 TGT 的数据...
# TGT 数据处理成功
# 正在处理 TEL 的数据...
# TEL 数据处理成功
# 正在处理 TDY 的数据...
# TDY 数据处理成功
# 正在处理 TFX 的数据...
# TFX 数据处理成功
# 正在处理 TER 的数据...
# TER 数据处理成功
# 正在处理 TSLA 的数据...
# TSLA 数据处理成功
# 正在处理 TXN 的数据...
# TXN 数据处理成功
# 正在处理 TPL 的数据...
# TPL 数据处理成功
# 正在处理 TXT 的数据...
# TXT 数据处理成功
# 正在处理 TMO 的数据...
# TMO 数据处理成功
# 正在处理 TJX 的数据...
# TJX 数据处理成功
# 正在处理 TSCO 的数据...
# TSCO 数据处理成功
# 正在处理 TT 的数据...
# TT 数据处理成功
# 正在处理 TDG 的数据...
# TDG 数据处理成功
# 正在处理 TRV 的数据...
# TRV 数据处理成功
# 正在处理 TRMB 的数据...
# TRMB 数据处理成功
# 正在处理 TFC 的数据...
# TFC 数据处理成功
# 正在处理 TYL 的数据...
# TYL 数据处理成功
# 正在处理 TSN 的数据...
# TSN 数据处理成功
# 正在处理 USB 的数据...
# USB 数据处理成功
# 正在处理 UBER 的数据...
# UBER 数据处理成功
# 正在处理 UDR 的数据...
# UDR 数据处理成功
# 正在处理 ULTA 的数据...
# ULTA 数据处理成功
# 正在处理 UNP 的数据...
# UNP 数据处理成功
# 正在处理 UAL 的数据...
# UAL 数据处理成功
# 正在处理 UPS 的数据...
# UPS 数据处理成功
# 正在处理 URI 的数据...
# URI 数据处理成功
# 正在处理 UNH 的数据...
# UNH 数据处理成功
# 正在处理 UHS 的数据...
# UHS 数据处理成功
# 正在处理 VLO 的数据...
# VLO 数据处理成功
# 正在处理 VTR 的数据...
# VTR 数据处理成功
# 正在处理 VLTO 的数据...
# VLTO 数据处理成功
# 正在处理 VRSN 的数据...
# VRSN 数据处理成功
# 正在处理 VRSK 的数据...
# VRSK 数据处理成功
# 正在处理 VZ 的数据...
# VZ 数据处理成功
# 正在处理 VRTX 的数据...
# VRTX 数据处理成功
# 正在处理 VTRS 的数据...
# VTRS 数据处理成功
# 正在处理 VICI 的数据...
# VICI 数据处理成功
# 正在处理 V 的数据...
# V 数据处理成功
# 正在处理 VST 的数据...
# VST 数据处理成功
# 正在处理 VMC 的数据...
# VMC 数据处理成功
# 正在处理 WRB 的数据...
# WRB 数据处理成功
# 正在处理 GWW 的数据...
# GWW 数据处理成功
# 正在处理 WAB 的数据...
# WAB 数据处理成功
# 正在处理 WBA 的数据...
# WBA 数据处理成功
# 正在处理 WMT 的数据...
# WMT 数据处理成功
# 正在处理 DIS 的数据...
# DIS 数据处理成功
# 正在处理 WBD 的数据...
# WBD 数据处理成功
# 正在处理 WM 的数据...
# WM 数据处理成功
# 正在处理 WAT 的数据...
# WAT 数据处理成功
# 正在处理 WEC 的数据...
# WEC 数据处理成功
# 正在处理 WFC 的数据...
# WFC 数据处理成功
# 正在处理 WELL 的数据...
# WELL 数据处理成功
# 正在处理 WST 的数据...
# WST 数据处理成功
# 正在处理 WDC 的数据...
# WDC 数据处理成功
# 正在处理 WY 的数据...
# WY 数据处理成功
# 正在处理 WMB 的数据...
# WMB 数据处理成功
# 正在处理 WTW 的数据...
# WTW 数据处理成功
# 正在处理 WDAY 的数据...
# WDAY 数据处理成功
# 正在处理 WYNN 的数据...
# WYNN 数据处理成功
# 正在处理 XEL 的数据...
# XEL 数据处理成功
# 正在处理 XYL 的数据...
# XYL 数据处理成功
# 正在处理 YUM 的数据...
# YUM 数据处理成功
# 正在处理 ZBRA 的数据...
# ZBRA 数据处理成功
# 正在处理 ZBH 的数据...
# ZBH 数据处理成功
# 正在处理 ZTS 的数据...
# ZTS 数据处理成功
